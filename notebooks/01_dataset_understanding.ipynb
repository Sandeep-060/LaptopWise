# %%
import pandas as pd

df = pd.read_csv("../data/raw/laptop_dataset.csv")

df.head()
# Out:
# C:\Users\SANDEEP\AppData\Local\Temp\ipykernel_25292\2529647307.py:3: DtypeWarning: Columns (0: Chipset, 1: RAM Speed, 2: Memory Slots, 3: SSD Type, 4: HDMI Ports, 5: Audio Solution, 6: Brightness, 7: Expandable Memory, 8: Thunderbolt Port, 9: VGA Port, 10: HDD Capacity, 11: HDD Speed(RPM), 12: HDD Type, 13: Lockport, 14: Battery Capacity, 15: Aspect Ratio, 16: SSD Interface, 17: Fast Charging Support) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/laptop_dataset.csv")
#   Brand                    Model                  Series  \
# 0    HP    14-dv0055TU (2N1L1PA)                Pavilion
# 1  Acer  PHN16-71 (NH.QLTSI.002)  Predator Helios Neo 16
# 2  Dell    15 5570 (A560126WIN9)             Inspiron 15
# 3   MSI         GV62 7RD-2297XIN                     NaN
# 4  Dell  15 3515 (D560702WIN9BE)             Inspiron 15
#
#                    Thickness       Dimensions (WxDxH)  \
# ...
